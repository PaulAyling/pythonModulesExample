# %%
import importlib
# run this if you edit the import module
# importlib.reload(a4)

import os,sys,inspect
current_dir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))


parent_dir = os.path.dirname(current_dir)
# have to add parents_parent_dir to go up a level
parents_parent_dir = os.path.dirname(parent_dir)
parents_parent_or_parent_dir = os.path.dirname(parents_parent_dir)
print(parent_dir)
print(parents_parent_dir)
print(parents_parent_or_parent_dir)
sys.path.insert(0, parents_parent_or_parent_dir) 

from common import a4
 
print("Execution of run starts")
a4.CommonFunction()
print("Execution of run finishes")
# Out:
# /Users/paul/Documents/dev/python/pythonModulesExample/examples/4_commonIsSiblingOfParentofParent/src/data_import_scripts
# /Users/paul/Documents/dev/python/pythonModulesExample/examples/4_commonIsSiblingOfParentofParent/src
# /Users/paul/Documents/dev/python/pythonModulesExample/examples/4_commonIsSiblingOfParentofParent
# Execution of run starts
# This is where a gets called : A4
# Execution of run finishes
